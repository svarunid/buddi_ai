# %%
import matplotlib.pyplot as plt
from main import x, y, model

# %%
pred_y = []
for i in x:
    pred_y.append(model.predict(i))

# %%
plt.plot(x, y, label="Actual Data")
plt.plot(x, pred_y, label="Predicted Data")
plt.legend()
plt.show()
